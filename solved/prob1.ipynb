# %%
sum3 = sum([ x * 3 for x in range(1, 334) if x % 5 != 0 ])
sum3
# Out:
# 133668

# %%
sum5 = sum([x * 5 for x in range(1, 200)])
sum5
# Out:
# 99500

# %%
sum3 + sum5
# Out:
# 233168

# %%
int(1000/3)
# Out:
# 333

# %%
list(range(1, int(1000/3)))[-1]
# Out:
# 332

# %%
333*3
# Out:
# 999
