# %% [markdown]
# The sum of the primes below $10$ is $2 + 3 + 5 + 7 = 17$.
# Find the sum of all the primes below two million.

# %%
ANSWER = 142913828922

# %%
import sys
sys.path.insert(0, '..')
from common.common import is_prime

# %%
sum(filter(is_prime, list(range(2,10))))
# Out:
# 17

# %%
# %%time
sum(filter(is_prime, range(2,2000000)))
# Out:
# CPU times: user 13 s, sys: 6.29 ms, total: 13 s
# Wall time: 13.2 s
# 143064092722

# %%
# %%time
sum = 0
for n in range(2, 2000000):
    if is_prime(n):
        sum += n
# Out:
# CPU times: user 13 s, sys: 11.9 ms, total: 13 s
# Wall time: 13.3 s
