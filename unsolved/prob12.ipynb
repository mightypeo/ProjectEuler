# %% [markdown]
# The sequence of triangle numbers is generated by adding the natural numbers. So the $7$<sup>th</sup> triangle number would be $1 + 2 + 3 + 4 + 5 + 6 + 7 = 28$. The first ten terms would be:
# $$1, 3, 6, 10, 15, 21, 28, 36, 45, 55, \dots$$
# Let us list the factors of the first seven triangle numbers:
# $$\begin{align}
# \mathbf 1 &amp;\colon 1\\
# \mathbf 3 &amp;\colon 1,3\\
# \mathbf 6 &amp;\colon 1,2,3,6\\
# \mathbf{10} &amp;\colon 1,2,5,10\\
# \mathbf{15} &amp;\colon 1,3,5,15\\
# \mathbf{21} &amp;\colon 1,3,7,21\\
# \mathbf{28} &amp;\colon 1,2,4,7,14,28
# \end{align}$$
# We can see that $28$ is the first triangle number to have over five divisors.
# What is the value of the first triangle number to have over five hundred divisors?

# %%
import math
def find_divisors(n):
    divisors = []
    for i in range(1, math.isqrt(n) + 1):
        if n % i == 0:
            divisors.append(i)
            if i != n // i:
                divisors.append(n // i)
    return divisors

# %%
len(find_divisors(99991000))
# Out:
# 32

# %%
# %%time
triangle = 0
for i in range(1, 100_000):
    triangle += i
    n_divisors = len(find_divisors(triangle))
    if n_divisors  == 500:
        print(f"{triangle} is the first triangle number with 500 divisors.")
        break
    if i % 10000 == 0:
        print(f"Checked up to triangle number {i}, which is {triangle} and has {n_divisors} divisors.")
# Out:
# Checked up to triangle number 10000, which is 50005000 and has 80 divisors.
# Checked up to triangle number 20000, which is 200010000 and has 200 divisors.
# Checked up to triangle number 30000, which is 450015000 and has 160 divisors.
# Checked up to triangle number 40000, which is 800020000 and has 240 divisors.
# Checked up to triangle number 50000, which is 1250025000 and has 192 divisors.
# Checked up to triangle number 60000, which is 1800030000 and has 200 divisors.
# Checked up to triangle number 70000, which is 2450035000 and has 80 divisors.
# Checked up to triangle number 80000, which is 3200040000 and has 280 divisors.
# Checked up to triangle number 90000, which is 4050045000 and has 120 divisors.
# CPU times: user 5min 22s, sys: 129 ms, total: 5min 22s
# Wall time: 5min 23s
